# %% [markdown]
# <a href="https://colab.research.google.com/github/tlsehdgns1999/tlsehdgns1999/blob/main/airline_delay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 필요 모듈 불러오기

import pandas as pd
import numpy as np
import os
import gc

# %%
### 베이스 라인 코드를 빌려옴(실행속도 향상)

def csv_to_parquet(csv_path, save_name):
     df = pd.read_csv(csv_path)
     df.to_parquet(f'./{save_name}.parquet')
     del df
     gc.collect()
     print(save_name, 'Done.')

train_path = 'data/train.csv'
test_path = 'data/test.csv'

csv_to_parquet(train_path, 'train')
csv_to_parquet(test_path, 'test')

train = pd.read_parquet('train.parquet')
test = pd.read_parquet('test.parquet')
sample_submission = pd.read_csv('data/sample_submission.csv', index_col = 0)
# Out:
# train Done.
# test Done.

# %%
### Month 와 Date를 한 가지의 days 컬럼으로 합치는 과정 (train, test 적용)

def days(x) :
    month_days = {1:0, 2:31, 3:60, 4:91, 5:121, 6:152, 7:182, 8:213, 9:244, 10:274, 11:305, 12:335}
    return month_days[x]

df_list = [train, test]
for i in range(len(df_list)) :
    df_list[i].loc[:, 'Day'] = train['Month'].apply(lambda x : days(x))
    df_list[i]['Day'] = df_list[i]['Day'] + df_list[i]['Day_of_Month']

train = train.astype({'Day': object})
test = test.astype({'Day': object})

### 'Month', 'Date' 컬럼 제거

train_new = train.drop([train.columns[1], train.columns[2]], axis = 1)
test_new = test.drop([test.columns[1], test.columns[2]], axis = 1)

# %%
### 'Carrier_ID(DOT)' 는 'Airline'에 일대일 대응되는 지표이다. 
### 일대일 대응 되는 지표가 있으면 대체 하는 과정 

carrier_code_mapping = train_new.groupby('Airline')['Carrier_ID(DOT)'].apply(lambda x: x.mode().iloc[0])
train_new['Carrier_ID(DOT)'] = train_new['Carrier_ID(DOT)'].fillna(train_new['Airline'].map(carrier_code_mapping))

# %%
airline_code_mapping = train_new.groupby('Carrier_ID(DOT)')['Airline'].apply(lambda x: x.mode().iloc[0])
train_new['Airline'] = train_new['Airline'].fillna(train_new['Carrier_ID(DOT)'].map(airline_code_mapping))

# %%
### 대응 후 남은 'Carrier_ID(DOT)', 'Airline' 의 결측치 

train_new.isnull().sum()
# Out:
# ID                               0
# Estimated_Departure_Time    109019
# Estimated_Arrival_Time      109040
# Cancelled                        0
# Diverted                         0
# Origin_Airport                   0
# Origin_Airport_ID                0
# Origin_State                109015
# Destination_Airport              0
# Destination_Airport_ID           0
# Destination_State           109079
# Distance                         0
# Airline                      11883
# Carrier_Code(IATA)          108990
# Carrier_ID(DOT)              11883
# Tail_Number                      0
# Delay                       744999
# Day                              0
# dtype: int64

# %%
### train set 이므로 남는 결측치는 전부 제거

train_new = train_new.dropna(subset = ['Carrier_ID(DOT)'], how='any', axis = 0)

# %%
train_new.isnull().sum()
# Out:
# ID                               0
# Estimated_Departure_Time    107726
# Estimated_Arrival_Time      107789
# Cancelled                        0
# Diverted                         0
# Origin_Airport                   0
# Origin_Airport_ID                0
# Origin_State                107739
# Destination_Airport              0
# Destination_Airport_ID           0
# Destination_State           107782
# Distance                         0
# Airline                          0
# Carrier_Code(IATA)          107717
# Carrier_ID(DOT)                  0
# Tail_Number                      0
# Delay                       736101
# Day                              0
# dtype: int64

# %%
### test도 같은 방식으로 진행, 하지만 없어지는 행이 없어야 하기 때문에 최빈값으로 대체하는 작업 필요

carrier_code_mapping2 = test_new.groupby('Airline')['Carrier_ID(DOT)'].apply(lambda x: x.mode().iloc[0])
test_new['Carrier_ID(DOT)'] = test_new['Carrier_ID(DOT)'].fillna(test_new['Airline'].map(carrier_code_mapping2))

# %%
airline_code_mapping2 = test_new.groupby('Carrier_ID(DOT)')['Airline'].apply(lambda x: x.mode().iloc[0])
test_new['Airline'] = test_new['Airline'].fillna(test_new['Carrier_ID(DOT)'].map(airline_code_mapping2))

# %%
test_new.isnull().sum()
# Out:
# ID                               0
# Estimated_Departure_Time    108984
# Estimated_Arrival_Time      109048
# Cancelled                        0
# Diverted                         0
# Origin_Airport                   0
# Origin_Airport_ID                0
# Origin_State                106505
# Destination_Airport              0
# Destination_Airport_ID           0
# Destination_State           106523
# Distance                         0
# Airline                      11543
# Carrier_Code(IATA)          108993
# Carrier_ID(DOT)              11543
# Tail_Number                      0
# Day                              0
# dtype: int64

# %%
from scipy.stats import mode

### 결측치 대체할 최빈값 계산
mode_value = test_new['Carrier_ID(DOT)'].mode().iloc[0]
test_new['Carrier_ID(DOT)'] = test_new['Carrier_ID(DOT)'].fillna(mode_value)

mode_value = test_new['Airline'].mode().iloc[0]
test_new['Airline'] = test_new['Airline'].fillna(mode_value)

# %%
test_new.isnull().sum()
# Out:
# ID                               0
# Estimated_Departure_Time    108984
# Estimated_Arrival_Time      109048
# Cancelled                        0
# Diverted                         0
# Origin_Airport                   0
# Origin_Airport_ID                0
# Origin_State                106505
# Destination_Airport              0
# Destination_Airport_ID           0
# Destination_State           106523
# Distance                         0
# Airline                          0
# Carrier_Code(IATA)          108993
# Carrier_ID(DOT)                  0
# Tail_Number                      0
# Day                              0
# dtype: int64

# %%
### 남는 열 제거(중복사항)

col_drop = ['Cancelled', 'Diverted', 'Origin_Airport', 'Destination_Airport', 'Carrier_Code(IATA)', 'Airline', 'Origin_State', 'Destination_State']
train_new = train_new.drop(col_drop, axis=1)
test_new = test_new.drop(col_drop, axis=1)

# %%
train_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 988117 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        988117 non-null  object
#  1   Estimated_Departure_Time  880391 non-null  float64
#  2   Estimated_Arrival_Time    880328 non-null  float64
#  3   Origin_Airport_ID         988117 non-null  int64
#  4   Destination_Airport_ID    988117 non-null  int64
#  5   Distance                  988117 non-null  float64
#  6   Carrier_ID(DOT)           988117 non-null  float64
#  7   Tail_Number               988117 non-null  object
#  8   Delay                     252016 non-null  object
#  9   Day                       988117 non-null  object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 82.9+ MB

# %%
test_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   ID                        1000000 non-null  object
#  1   Estimated_Departure_Time  891016 non-null   float64
#  2   Estimated_Arrival_Time    890952 non-null   float64
#  3   Origin_Airport_ID         1000000 non-null  int64
#  4   Destination_Airport_ID    1000000 non-null  int64
#  5   Distance                  1000000 non-null  float64
#  6   Carrier_ID(DOT)           1000000 non-null  float64
#  7   Tail_Number               1000000 non-null  object
#  8   Day                       1000000 non-null  object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 68.7+ MB

# %%
train_new.head()
# Out:
#              ID  Estimated_Departure_Time  Estimated_Arrival_Time
# 0  TRAIN_000000                       NaN                     NaN  \
# 1  TRAIN_000001                     740.0                  1024.0
# 2  TRAIN_000002                    1610.0                  1805.0
# 3  TRAIN_000003                     905.0                  1735.0
# 4  TRAIN_000004                     900.0                  1019.0
#
#    Origin_Airport_ID  Destination_Airport_ID  Distance  Carrier_ID(DOT)
# 0              13851                   12191     419.0          19393.0  \
# 1              13930                   14869    1250.0          20304.0
# 2              11057                   12953     544.0          19805.0
# 3              12892                   11618    2454.0          19977.0
# 4              14771                   10157     250.0          20304.0
#
#   Tail_Number Delay  Day
# 0      N7858A  None  106
# 1      N125SY  None  228
# 2      N103US  None  250
# 3      N595UA  None  192
# 4      N161SY  None   11

# %%
### 이 작업은 대강의 분 차이를 이용해 출발 또는 도착의 시간을 예상해 결측치를 채워넣는 방법이다.

### 먼저 'HHMM' 를 분으로 변환

def con_to_minutes(x) :
    if np.isnan(x) :
        return np.nan
    else:
        x = int(x)
        x = str(x)
        if len(x) > 2 :
            # 시간과 분으로 나눔
            hours = int(x[:-2])
            mins = int(x[-2:])
        else :
            hours = 0
            mins = int(x[-2:])
        return hours * 60 + mins

### 'Estimated_Departure_Time' 열의 값을 분으로 변환

train_new['Estimated_Departure_Time'] = train_new['Estimated_Departure_Time'].apply(con_to_minutes)

### 'Estimated_Arrival_Time' 열의 값을 분으로 변환

train_new['Estimated_Arrival_Time'] = train_new['Estimated_Arrival_Time'].apply(con_to_minutes)

# %%
train_new = train_new.dropna(subset = ['Estimated_Arrival_Time', 'Estimated_Departure_Time'], how = 'all', axis = 0)

# %%
train_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 976567 entries, 1 to 999999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        976567 non-null  object
#  1   Estimated_Departure_Time  880391 non-null  float64
#  2   Estimated_Arrival_Time    880328 non-null  float64
#  3   Origin_Airport_ID         976567 non-null  int64
#  4   Destination_Airport_ID    976567 non-null  int64
#  5   Distance                  976567 non-null  float64
#  6   Carrier_ID(DOT)           976567 non-null  float64
#  7   Tail_Number               976567 non-null  object
#  8   Delay                     249021 non-null  object
#  9   Day                       976567 non-null  object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 82.0+ MB

# %%
### Origin_Airport_ID와 Destination_Airport_ID를 키로, 평균 비행시간을 값으로 갖는 디렉토리 생성

from collections import defaultdict

time_flying = defaultdict(int)
time_number = defaultdict(int)

cond = ~train_new['Estimated_Arrival_Time'].isnull() & ~train_new['Estimated_Departure_Time'].isnull()

for _, row in train_new[cond].iterrows():
    origin, dest = row['Origin_Airport_ID'], row['Destination_Airport_ID']
    flying_time = (row['Estimated_Arrival_Time'] - row['Estimated_Departure_Time']) % 1440
    time_flying[(origin, dest)] += flying_time
    time_number[(origin, dest)] += 1

for key in time_flying:
    time_flying[key] /= time_number[key]

# %%
### 결측값 채우기

for idx, row in train_new[train_new['Origin_Airport_ID'].isnull() | train_new['Destination_Airport_ID'].isnull()].iterrows():
    origin, dest = row['Origin_Airport_ID'], row['Destination_Airport_ID']
    if origin in time_flying and not pd.isnull(origin):
        train_new.at[idx, 'Origin_Airport_ID'] = origin
    if dest in time_flying and not pd.isnull(dest):
        train_new.loc[idx, 'Destination_Airport_ID'] = dest
        train_new.loc[idx, 'Flying_Time'] = time_flying[(origin, dest)]

# %%
### Estimated_Arrival_Time - Estimated_Departure_Time 을 계산해 같은 출발, 도착지를 갖는 행의 결측치를 채움

mask_dep = train_new['Estimated_Departure_Time'].isnull()
mask_arr = train_new['Estimated_Arrival_Time'].isnull()

train_new.loc[mask_dep, 'Estimated_Departure_Time'] = train_new.loc[mask_dep].apply(lambda row: (row['Estimated_Arrival_Time'] - time_flying[(row['Origin_Airport_ID'], row['Destination_Airport_ID'])]) % 1440, axis=1)
train_new.loc[mask_arr, 'Estimated_Arrival_Time'] = train_new.loc[mask_arr].apply(lambda row: (row['Estimated_Departure_Time'] + time_flying[(row['Origin_Airport_ID'], row['Destination_Airport_ID'])]) % 1440, axis=1)

# %%
### test의 결측치를 최빈값으로 대체

mode_dep = test_new['Estimated_Departure_Time'].mode().iloc[0]
mode_arr = test_new['Estimated_Arrival_Time'].mode().iloc[0]

test_new['Estimated_Departure_Time'].fillna(mode_dep, inplace=True)
test_new['Estimated_Arrival_Time'].fillna(mode_arr, inplace=True)

# %%
### Dealy 의 NaN 값 제거 (라벨링 된 데이터로만 추론 진행)

train_new = train_new.dropna()

# %%
### Delayed, Not_Delayed 를 0, 1 로 카테고리 화, astype을 쓰지 않은 이유는 변환을 명확히 하기 위함

train_new['Delay'] = train_new['Delay'].replace('Delayed', 1)
train_new['Delay'] = train_new['Delay'].replace('Not_Delayed', 0)

# %%
### test셋에 비해 train셋의 양이 현저히 적어졌으므로 validation셋을 생성

from sklearn.model_selection import train_test_split


X = train_new.drop(columns=['ID', 'Delay'], axis = 1)
y = train_new['Delay']
test_val = test_new.drop(columns=['ID'])
X_train, X_valid , y_train, y_valid = train_test_split(X, y, test_size = 0.2, stratify = y)

# %%
### xgb 학습을 위해 질적 변수를 양적 변수로 변환함

from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

q_col = ['Tail_Number', 'Day']

for i in q_col:
    le = LabelEncoder()
    le=le.fit(X_train[i])
    X_train[i]=le.transform(X_train[i])

    for label in np.unique(X_valid[i]):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    X_valid[i]=le.transform(X_valid[i])

    for label in np.unique(test_new[i]):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    test_new[i]=le.transform(test_new[i])
print('Done.')
# Out:
# Done.

# %%
### 모델링

model = XGBClassifier(
                      booster = 'gbtree',
                      scale_pos_weight=5,
                      learning_rate=0.01,  
                      colsample_bytree = 0.7,
                      subsample = 0.5,
                      max_delta_step = 3,
                      reg_lambda = 2,
                     objective='binary:logistic',
                      n_estimators=818, 
                      max_depth=8,
                     )

# %%
# %%time
eval_set = [(X_valid, y_valid)]
eval_metric = ["logloss"]
model.fit(X_train, y_train,early_stopping_rounds=50, eval_metric=eval_metric, eval_set = eval_set)
# Out:
# [0]	validation_0-logloss:0.69277
# C:\Users\cjswo\anaconda3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users
# [234]	validation_0-logloss:0.66213
# [235]	validation_0-logloss:0.66211
# [236]	validation_0-logloss:0.66209
# [237]	validation_0-logloss:0.66200
# [238]	validation_0-logloss:0.66200
# [239]	validation_0-logloss:0.66194
# [240]	validation_0-logloss:0.66188
# [241]	validation_0-logloss:0.66183
# [242]	validation_0-logloss:0.66174
# [243]	validation_0-logloss:0.66167
# [244]	validation_0-logloss:0.66158
# [245]	validation_0-logloss:0.66152
# [246]	validation_0-logloss:0.66148
# [247]	validation_0-logloss:0.66146
# [248]	validation_0-logloss:0.66142
# [249]	validation_0-logloss:0.66137
# [250]	validation_0-logloss:0.66138
# [251]	validation_0-logloss:0.66133
# [252]	validation_0-logloss:0.66127
# [253]	validation_0-logloss:0.66119
# [254]	validation_0-logloss:0.66111
# [255]	validation_0-logloss:0.66109
# [256]	validation_0-logloss:0.66106
# [257]	validation_0-logloss:0.66101
# [258]	validation_0-logloss:0.66096
# [259]	validation_0-logloss:0.66088
# [260]	validation_0-logloss:0.66085
# [261]	validation_0-logloss:0.66082
# [262]	validation_0-logloss:0.66078
# [263]	validation_0-logloss:0.66075
# [264]	validation_0-logloss:0.66069
# [265]	validation_0-logloss:0.66063
# [266]	validation_0-logloss:0.66056
# [267]	validation_0-logloss:0.66053
# [268]	validation_0-logloss:0.66049
# [269]	validation_0-logloss:0.66048
# [270]	validation_0-logloss:0.66046
# [271]	validation_0-logloss:0.66040
# [272]	validation_0-logloss:0.66038
# [273]	validation_0-logloss:0.66032
# [274]	validation_0-logloss:0.66025
# [275]	validation_0-logloss:0.66022
# [276]	validation_0-logloss:0.66023
# [277]	validation_0-logloss:0.66019
# [278]	validation_0-logloss:0.66014
# [279]	validation_0-logloss:0.66012
# [280]	validation_0-logloss:0.66005
# [281]	validation_0-logloss:0.66001
# [282]	validation_0-logloss:0.65996
# [283]	validation_0-logloss:0.65990
# [284]	validation_0-logloss:0.65985
# [285]	validation_0-logloss:0.65985
# [286]	validation_0-logloss:0.65980
# [287]	validation_0-logloss:0.65976
# [288]	validation_0-logloss:0.65967
# [289]	validation_0-logloss:0.65963
# [290]	validation_0-logloss:0.65958
# [291]	validation_0-logloss:0.65954
# [292]	validation_0-logloss:0.65950
# [293]	validation_0-logloss:0.65946
# [294]	validation_0-logloss:0.65939
# [295]	validation_0-logloss:0.65937
# [296]	validation_0-logloss:0.65934
# [297]	validation_0-logloss:0.65931
# [298]	validation_0-logloss:0.65928
# [299]	validation_0-logloss:0.65927
# [300]	validation_0-logloss:0.65926
# [301]	validation_0-logloss:0.65920
# [302]	validation_0-logloss:0.65915
# [303]	validation_0-logloss:0.65915
# [304]	validation_0-logloss:0.65912
# [305]	validation_0-logloss:0.65910
# [306]	validation_0-logloss:0.65901
# [307]	validation_0-logloss:0.65896
# [308]	validation_0-logloss:0.65890
# [309]	validation_0-logloss:0.65887
# [310]	validation_0-logloss:0.65883
# [311]	validation_0-logloss:0.65879
# [312]	validation_0-logloss:0.65882
# [313]	validation_0-logloss:0.65877
# [314]	validation_0-logloss:0.65877
# [315]	validation_0-logloss:0.65868
# [316]	validation_0-logloss:0.65866
# [317]	validation_0-logloss:0.65866
# [318]	validation_0-logloss:0.65861
# [319]	validation_0-logloss:0.65859
# [320]	validation_0-logloss:0.65854
# [321]	validation_0-logloss:0.65846
# [322]	validation_0-logloss:0.65840
# [323]	validation_0-logloss:0.65835
# [324]	validation_0-logloss:0.65830
# [325]	validation_0-logloss:0.65825
# [326]	validation_0-logloss:0.65820
# [327]	validation_0-logloss:0.65817
# [328]	validation_0-logloss:0.65812
# [329]	validation_0-logloss:0.65813
# [330]	validation_0-logloss:0.65810
# [331]	validation_0-logloss:0.65807
# [332]	validation_0-logloss:0.65806
# [333]	validation_0-logloss:0.65801
# [334]	validation_0-logloss:0.65801
# [335]	validation_0-logloss:0.65797
# [336]	validation_0-logloss:0.65794
# [337]	validation_0-logloss:0.65789
# [338]	validation_0-logloss:0.65786
# [339]	validation_0-logloss:0.65782
# [340]	validation_0-logloss:0.65779
# [341]	validation_0-logloss:0.65778
# [342]	validation_0-logloss:0.65773
# [343]	validation_0-logloss:0.65766
# [344]	validation_0-logloss:0.65761
# [345]	validation_0-logloss:0.65758
# [346]	validation_0-logloss:0.65754
# [347]	validation_0-logloss:0.65753
# [348]	validation_0-logloss:0.65751
# [349]	validation_0-logloss:0.65746
# [350]	validation_0-logloss:0.65742
# [351]	validation_0-logloss:0.65740
# [352]	validation_0-logloss:0.65733
# [353]	validation_0-logloss:0.65727
# [354]	validation_0-logloss:0.65720
# [355]	validation_0-logloss:0.65720
# [356]	validation_0-logloss:0.65714
# [357]	validation_0-logloss:0.65712
# [358]	validation_0-logloss:0.65710
# [359]	validation_0-logloss:0.65708
# [360]	validation_0-logloss:0.65711
# [361]	validation_0-logloss:0.65706
# [362]	validation_0-logloss:0.65705
# [363]	validation_0-logloss:0.65700
# [364]	validation_0-logloss:0.65694
# [365]	validation_0-logloss:0.65694
# [366]	validation_0-logloss:0.65687
# [367]	validation_0-logloss:0.65684
# [368]	validation_0-logloss:0.65682
# [369]	validation_0-logloss:0.65677
# [370]	validation_0-logloss:0.65674
# [371]	validation_0-logloss:0.65673
# [372]	validation_0-logloss:0.65664
# [373]	validation_0-logloss:0.65658
# [374]	validation_0-logloss:0.65655
# [375]	validation_0-logloss:0.65653
# [376]	validation_0-logloss:0.65650
# [377]	validation_0-logloss:0.65644
# [378]	validation_0-logloss:0.65639
# [379]	validation_0-logloss:0.65636
# [380]	validation_0-logloss:0.65632
# [381]	validation_0-logloss:0.65629
# [382]	validation_0-logloss:0.65627
# [383]	validation_0-logloss:0.65624
# [384]	validation_0-logloss:0.65619
# [385]	validation_0-logloss:0.65619
# [386]	validation_0-logloss:0.65611
# [387]	validation_0-logloss:0.65603
# [388]	validation_0-logloss:0.65600
# [389]	validation_0-logloss:0.65594
# [390]	validation_0-logloss:0.65593
# [391]	validation_0-logloss:0.65586
# [392]	validation_0-logloss:0.65585
# [393]	validation_0-logloss:0.65579
# [394]	validation_0-logloss:0.65572
# [395]	validation_0-logloss:0.65567
# [396]	validation_0-logloss:0.65569
# [397]	validation_0-logloss:0.65567
# [398]	validation_0-logloss:0.65568
# [399]	validation_0-logloss:0.65562
# [400]	validation_0-logloss:0.65563
# [401]	validation_0-logloss:0.65564
# [402]	validation_0-logloss:0.65562
# [403]	validation_0-logloss:0.65560
# [404]	validation_0-logloss:0.65557
# [405]	validation_0-logloss:0.65559
# [406]	validation_0-logloss:0.65557
# [407]	validation_0-logloss:0.65552
# [408]	validation_0-logloss:0.65546
# [409]	validation_0-logloss:0.65540
# [410]	validation_0-logloss:0.65540
# [411]	validation_0-logloss:0.65537
# [412]	validation_0-logloss:0.65534
# [413]	validation_0-logloss:0.65534
# [414]	validation_0-logloss:0.65531
# [415]	validation_0-logloss:0.65529
# [416]	validation_0-logloss:0.65521
# [417]	validation_0-logloss:0.65516
# [418]	validation_0-logloss:0.65516
# [419]	validation_0-logloss:0.65507
# [420]	validation_0-logloss:0.65507
# [421]	validation_0-logloss:0.65502
# [422]	validation_0-logloss:0.65493
# [423]	validation_0-logloss:0.65491
# [424]	validation_0-logloss:0.65486
# [425]	validation_0-logloss:0.65484
# [426]	validation_0-logloss:0.65476
# [427]	validation_0-logloss:0.65474
# [428]	validation_0-logloss:0.65473
# [429]	validation_0-logloss:0.65473
# [430]	validation_0-logloss:0.65471
# [431]	validation_0-logloss:0.65469
# [432]	validation_0-logloss:0.65465
# [433]	validation_0-logloss:0.65460
# [434]	validation_0-logloss:0.65452
# [435]	validation_0-logloss:0.65451
# [436]	validation_0-logloss:0.65449
# [437]	validation_0-logloss:0.65444
# [438]	validation_0-logloss:0.65441
# [439]	validation_0-logloss:0.65439
# [440]	validation_0-logloss:0.65436
# [441]	validation_0-logloss:0.65432
# [442]	validation_0-logloss:0.65431
# [443]	validation_0-logloss:0.65427
# [444]	validation_0-logloss:0.65420
# [445]	validation_0-logloss:0.65416
# [446]	validation_0-logloss:0.65414
# [447]	validation_0-logloss:0.65410
# [448]	validation_0-logloss:0.65406
# [449]	validation_0-logloss:0.65404
# [450]	validation_0-logloss:0.65400
# [451]	validation_0-logloss:0.65397
# [452]	validation_0-logloss:0.65389
# [453]	validation_0-logloss:0.65390
# [454]	validation_0-logloss:0.65387
# [455]	validation_0-logloss:0.65383
# [456]	validation_0-logloss:0.65378
# [457]	validation_0-logloss:0.65375
# [458]	validation_0-logloss:0.65368
# [459]	validation_0-logloss:0.65369
# [460]	validation_0-logloss:0.65368
# [461]	validation_0-logloss:0.65362
# [462]	validation_0-logloss:0.65357
# [463]	validation_0-logloss:0.65355
# [464]	validation_0-logloss:0.65351
# [465]	validation_0-logloss:0.65343
# [466]	validation_0-logloss:0.65338
# [467]	validation_0-logloss:0.65334
# [468]	validation_0-logloss:0.65327
# [469]	validation_0-logloss:0.65321
# [470]	validation_0-logloss:0.65321
# [471]	validation_0-logloss:0.65316
# [472]	validation_0-logloss:0.65313
# [473]	validation_0-logloss:0.65311
# [474]	validation_0-logloss:0.65308
# [475]	validation_0-logloss:0.65305
# [476]	validation_0-logloss:0.65302
# [477]	validation_0-logloss:0.65300
# [478]	validation_0-logloss:0.65291
# [479]	validation_0-logloss:0.65289
# [480]	validation_0-logloss:0.65286
# [481]	validation_0-logloss:0.65283
# [482]	validation_0-logloss:0.65284
# [483]	validation_0-logloss:0.65282
# [484]	validation_0-logloss:0.65276
# [485]	validation_0-logloss:0.65274
# [486]	validation_0-logloss:0.65270
# [487]	validation_0-logloss:0.65266
# [488]	validation_0-logloss:0.65262
# [489]	validation_0-logloss:0.65264
# [490]	validation_0-logloss:0.65262
# [491]	validation_0-logloss:0.65253
# [492]	validation_0-logloss:0.65253
# [493]	validation_0-logloss:0.65245
# [494]	validation_0-logloss:0.65240
# [495]	validation_0-logloss:0.65240
# [496]	validation_0-logloss:0.65239
# [497]	validation_0-logloss:0.65238
# [498]	validation_0-logloss:0.65236
# [499]	validation_0-logloss:0.65231
# [500]	validation_0-logloss:0.65227
# [501]	validation_0-logloss:0.65222
# [502]	validation_0-logloss:0.65220
# [503]	validation_0-logloss:0.65216
# [504]	validation_0-logloss:0.65213
# [505]	validation_0-logloss:0.65211
# [506]	validation_0-logloss:0.65212
# [507]	validation_0-logloss:0.65206
# [508]	validation_0-logloss:0.65204
# [509]	validation_0-logloss:0.65199
# [510]	validation_0-logloss:0.65201
# [511]	validation_0-logloss:0.65195
# [512]	validation_0-logloss:0.65193
# [513]	validation_0-logloss:0.65189
# [514]	validation_0-logloss:0.65188
# [515]	validation_0-logloss:0.65180
# [516]	validation_0-logloss:0.65182
# [517]	validation_0-logloss:0.65179
# [518]	validation_0-logloss:0.65177
# [519]	validation_0-logloss:0.65171
# [520]	validation_0-logloss:0.65168
# [521]	validation_0-logloss:0.65163
# [522]	validation_0-logloss:0.65159
# [523]	validation_0-logloss:0.65155
# [524]	validation_0-logloss:0.65155
# [525]	validation_0-logloss:0.65149
# [526]	validation_0-logloss:0.65151
# [527]	validation_0-logloss:0.65146
# [528]	validation_0-logloss:0.65141
# [529]	validation_0-logloss:0.65138
# [530]	validation_0-logloss:0.65136
# [531]	validation_0-logloss:0.65136
# [532]	validation_0-logloss:0.65133
# [533]	validation_0-logloss:0.65130
# [534]	validation_0-logloss:0.65129
# [535]	validation_0-logloss:0.65120
# [536]	validation_0-logloss:0.65118
# [537]	validation_0-logloss:0.65117
# [538]	validation_0-logloss:0.65106
# [539]	validation_0-logloss:0.65103
# [540]	validation_0-logloss:0.65100
# [541]	validation_0-logloss:0.65102
# [542]	validation_0-logloss:0.65092
# [543]	validation_0-logloss:0.65092
# [544]	validation_0-logloss:0.65090
# [545]	validation_0-logloss:0.65089
# [546]	validation_0-logloss:0.65084
# [547]	validation_0-logloss:0.65079
# [548]	validation_0-logloss:0.65077
# [549]	validation_0-logloss:0.65076
# [550]	validation_0-logloss:0.65071
# [551]	validation_0-logloss:0.65067
# [552]	validation_0-logloss:0.65066
# [553]	validation_0-logloss:0.65067
# [794]	validation_0-logloss:0.64478
# [795]	validation_0-logloss:0.64479
# [796]	validation_0-logloss:0.64476
# [797]	validation_0-logloss:0.64474
# [798]	validation_0-logloss:0.64474
# [799]	validation_0-logloss:0.64475
# [800]	validation_0-logloss:0.64473
# [801]	validation_0-logloss:0.64475
# [802]	validation_0-logloss:0.64472
# [803]	validation_0-logloss:0.64469
# [804]	validation_0-logloss:0.64465
# [805]	validation_0-logloss:0.64462
# [806]	validation_0-logloss:0.64463
# [807]	validation_0-logloss:0.64460
# [808]	validation_0-logloss:0.64460
# [809]	validation_0-logloss:0.64458
# [810]	validation_0-logloss:0.64456
# [811]	validation_0-logloss:0.64455
# [812]	validation_0-logloss:0.64451
# [813]	validation_0-logloss:0.64448
# [814]	validation_0-logloss:0.64447
# [815]	validation_0-logloss:0.64446
# [816]	validation_0-logloss:0.64443
# [817]	validation_0-logloss:0.64441
# Wall time: 55.6 s
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None, max_delta_step=3,
#               max_depth=8, max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=818, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None, ...)

# %%
predictions = model.predict_proba(X_valid)
predictions
# Out:
# array([[0.56815386, 0.43184614],
#        [0.4873038 , 0.5126962 ],
#        [0.3070565 , 0.6929435 ],
#        ...,
#        [0.67282385, 0.32717615],
#        [0.6016617 , 0.39833832],
#        [0.4602949 , 0.5397051 ]], dtype=float32)

# %%
predictions = model.predict_proba(test_new)
predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6192\3259101399.py in <module>
# ----> 1 predictions = model.predict_proba(test_new)
#       2 predictions
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in predict_proba(self, X, ntree_limit, validate_features, base_margin, iteration_range)
#    1604             class_prob = softmax(raw_predt, axis=1)
#    1605             return class_prob
# -> 1606         class_probs = super().predict(
#    1607             X=X,
#    1608             ntree_limit=ntree_limit,
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1112             if self._can_use_inplace_predict():
#    1113                 try:
# -> 1114                     predts = self.get_booster().inplace_predict(
#    1115                         data=X,
#    1116                         iteration_range=iteration_range,
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2267                 )
#    2268             if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 2269                 raise ValueError(
#    2270                     f"Feature shape mismatch, expected: {self.num_features()}, "
#    2271                     f"got {data.shape[1]}"
#
# ValueError: Feature shape mismatch, expected: 8, got 9

# %%
sample_submission = pd.read_csv('data/sample_submission.csv', index_col = 0)

# %%
submission = pd.DataFrame(data=predictions, columns=sample_submission.columns, index=sample_submission.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6192\2582220364.py in <module>
# ----> 1 submission = pd.DataFrame(data=predictions, columns=sample_submission.columns, index=sample_submission.index)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     756                 )
#     757             else:
# --> 758                 mgr = ndarray_to_mgr(
#     759                     data,
#     760                     index,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     335     )
#     336
# --> 337     _check_values_indices_shape_match(values, index, columns)
#     338
#     339     if typ == "array":
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _check_values_indices_shape_match(values, index, columns)
#     406         passed = values.shape
#     407         implied = (len(index), len(columns))
# --> 408         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     409
#     410
#
# ValueError: Shape of passed values is (49805, 2), indices imply (1000000, 2)

# %%
submission.to_csv('data/sample_submission.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6192\676064065.py in <module>
# ----> 1 submission.to_csv('data/sample_submission.csv', index=True)
#
# NameError: name 'submission' is not defined
